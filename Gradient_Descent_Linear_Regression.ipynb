# %% [markdown]
# # Linear Regression with Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Create data

# %%
x = np.arange(1, 11)

# Create random values for y
y = 10 + 3*x + 5*np.random.randn(10) + 10
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# ## 2. Calculate coefficients using Normal Equations

# %%
# Design matrix X = [1 x]
X = np.concatenate((np.ones((10,1)), x.reshape(10,1)), axis=1)

# Target values y
Y = y.reshape((10,1))

# Calculate the regression coefficients
M1 = np.linalg.inv(np.dot(X.T, X)).dot(X.T).dot(Y)

z = X.dot(M1)
plt.plot(x, z)
plt.plot(x, y, 'o')

print(M)
print('Mean absolute error is {0:5.4f}.'.format(np.sum(np.abs(Y - X.dot(M1)))))
plt.show()
# Out:
# [[22.14286795]
#  [ 2.32231998]]
# Mean absolute error is 35.6036.

# %% [markdown]
# ## 3. Calculate coefficients using Gradient Descent

# %%
alpha = 0.001
M = np.random.rand(2,1)

for epoch in range(10000):
    dS = 2*X.T.dot((X.dot(M) - Y))
    M = M - alpha*dS

z = X.dot(M)
plt.plot(x, z)
plt.plot(x, y, 'o')

print(M)
print('Mean absolute error is {0:5.4f}.'.format(np.sum(np.abs(Y - X.dot(M)))))
plt.show()
# Out:
# [[22.14286795]
#  [ 2.32231998]]
# Mean absolute error is 35.6036.
